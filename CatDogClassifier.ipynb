# %% [markdown]
# # Using Inception to classify Cats and Dogs
#
# This repo uses TensorFlow to retrain the [Inception](https://github.com/tensorflow/models/tree/master/inception) Convolutional Neural Net (CNN) trained on [ImageNet](http://www.image-net.org).
#
# Here we are retraining the last layer of the CNN to classify images of cats and dogs. The data set used comes from the [Dogs v Cats Kaggle competition](https://www.kaggle.com/c/dogs-vs-cats).
#
# You will need an appropriate installation of TensorFlow. You are also recommended to take a look at this [TensorFlow repo in GitHub](https://github.com/tensorflow/tensorflow).
#
# ## Steps
#
# 1. Download the data from the [Dogs v Cats Kaggle competition](https://www.kaggle.com/c/dogs-vs-cats). You will need to move the cat pictures to a folder called `.\data\cats` and the dog ones to a folder called `.\data\dogs`
# 2. You may also want to partition the data set into a 80/70% training and 20/30% testing.
# 3. Follow the code below

# %% [markdown]
# Let us make sure that we are working on a suitable directory

# %%
import os
mypath = './'
os.chdir(mypath)

# %% [markdown]
# We are now going to use a `retrain` script provided by Google to train the last layer of the CNN. The script expects the following inputs:
#
# * --bottleneck_dir: A directory where image bottlenecks (pre-processing) will be stored
# * ----how_many_training_steps: The number of training steps to run
# * --model_dir: The directory where the Inception model will be downloaded/is stored
# * --output_graph: Path and file name where the TF graph will be stored
# * --output_labels: Path and file name where the labels for classification will be stores
# * --image_dir: Directory where the (cat and dog) folders live
#
# The first time you run this code it will take quite some time as the bottlenecks will have to be processed.

# %%
run ./retrain.py \
--bottleneck_dir=./bottlenecks \
--how_many_training_steps 500 \
--model_dir=./inception \
--output_graph=./retrained_graph.pb \
--output_labels=./retrained_labels.txt \
--image_dir ../data/train/ \
# Out:
# Looking for images in 'cats'
# Looking for images in 'dogs'
# 100 bottleneck files created.
# 200 bottleneck files created.
# 300 bottleneck files created.
# 400 bottleneck files created.
# 500 bottleneck files created.
# 600 bottleneck files created.
# 700 bottleneck files created.
# 800 bottleneck files created.
# 900 bottleneck files created.
# 1000 bottleneck files created.
# 1100 bottleneck files created.
# 1200 bottleneck files created.
# 1300 bottleneck files created.
# 1400 bottleneck files created.
# 1500 bottleneck files created.
# 1600 bottleneck files created.
# 1700 bottleneck files created.
# 1800 bottleneck files created.
# 1900 bottleneck files created.
# 2000 bottleneck files created.
# 2100 bottleneck files created.
# 2200 bottleneck files created.
# 2300 bottleneck files created.
# 2400 bottleneck files created.
# 2500 bottleneck files created.
# 2600 bottleneck files created.
# 2700 bottleneck files created.
# 2800 bottleneck files created.
# 2900 bottleneck files created.
# 3000 bottleneck files created.
# 3100 bottleneck files created.
# 3200 bottleneck files created.
# 3300 bottleneck files created.
# 3400 bottleneck files created.
# 3500 bottleneck files created.
# 3600 bottleneck files created.
# 3700 bottleneck files created.
# 3800 bottleneck files created.
# 3900 bottleneck files created.
# 4000 bottleneck files created.
# 4100 bottleneck files created.
# 4200 bottleneck files created.
# 4300 bottleneck files created.
# 4400 bottleneck files created.
# 4500 bottleneck files created.
# 4600 bottleneck files created.
# 4700 bottleneck files created.
# 4800 bottleneck files created.
# 4900 bottleneck files created.
# 5000 bottleneck files created.
# 5100 bottleneck files created.
# 5200 bottleneck files created.
# 5300 bottleneck files created.
# 5400 bottleneck files created.
# 5500 bottleneck files created.
# 5600 bottleneck files created.
# 5700 bottleneck files created.
# 5800 bottleneck files created.
# 5900 bottleneck files created.
# 6000 bottleneck files created.
# 6100 bottleneck files created.
# 6200 bottleneck files created.
# 6300 bottleneck files created.
# 6400 bottleneck files created.
# 6500 bottleneck files created.
# 6600 bottleneck files created.
# 6700 bottleneck files created.
# 6800 bottleneck files created.
# 6900 bottleneck files created.
# 7000 bottleneck files created.
# 7100 bottleneck files created.
# 7200 bottleneck files created.
# 7300 bottleneck files created.
# 7400 bottleneck files created.
# 7500 bottleneck files created.
# 7600 bottleneck files created.
# 7700 bottleneck files created.
# 7800 bottleneck files created.
# 7900 bottleneck files created.
# 8000 bottleneck files created.
# 8100 bottleneck files created.
# 8200 bottleneck files created.
# 8300 bottleneck files created.
# 8400 bottleneck files created.
# 8500 bottleneck files created.
# 8600 bottleneck files created.
# 8700 bottleneck files created.
# 8800 bottleneck files created.
# 8900 bottleneck files created.
# 9000 bottleneck files created.
# 9100 bottleneck files created.
# 9200 bottleneck files created.
# 9300 bottleneck files created.
# 9400 bottleneck files created.
# 9500 bottleneck files created.
# 9600 bottleneck files created.
# 9700 bottleneck files created.
# 9800 bottleneck files created.
# 9900 bottleneck files created.
# 10000 bottleneck files created.
# 10100 bottleneck files created.
# 10200 bottleneck files created.
# 10300 bottleneck files created.
# 10400 bottleneck files created.
# 10500 bottleneck files created.
# 10600 bottleneck files created.
# 10700 bottleneck files created.
# 10800 bottleneck files created.
# 10900 bottleneck files created.
# 11000 bottleneck files created.
# 11100 bottleneck files created.
# 11200 bottleneck files created.
# 11300 bottleneck files created.
# 11400 bottleneck files created.
# 11500 bottleneck files created.
# 11600 bottleneck files created.
# 11700 bottleneck files created.
# 11800 bottleneck files created.
# 11900 bottleneck files created.
# 12000 bottleneck files created.
# 12100 bottleneck files created.
# 12200 bottleneck files created.
# 12300 bottleneck files created.
# 12400 bottleneck files created.
# 12500 bottleneck files created.
# 12600 bottleneck files created.
# 12700 bottleneck files created.
# 12800 bottleneck files created.
# 12900 bottleneck files created.
# 13000 bottleneck files created.
# 13100 bottleneck files created.
# 13200 bottleneck files created.
# 13300 bottleneck files created.
# 13400 bottleneck files created.
# 13500 bottleneck files created.
# 13600 bottleneck files created.
# 13700 bottleneck files created.
# 13800 bottleneck files created.
# 13900 bottleneck files created.
# 14000 bottleneck files created.
# 14100 bottleneck files created.
# 14200 bottleneck files created.
# 14300 bottleneck files created.
# 14400 bottleneck files created.
# 14500 bottleneck files created.
# 14600 bottleneck files created.
# 14700 bottleneck files created.
# 14800 bottleneck files created.
# 14900 bottleneck files created.
# 15000 bottleneck files created.
# 15100 bottleneck files created.
# 15200 bottleneck files created.
# 15300 bottleneck files created.
# 15400 bottleneck files created.
# 15500 bottleneck files created.
# 15600 bottleneck files created.
# 15700 bottleneck files created.
# 15800 bottleneck files created.
# 15900 bottleneck files created.
# 16000 bottleneck files created.
# 16100 bottleneck files created.
# 16200 bottleneck files created.
# 16300 bottleneck files created.
# 16400 bottleneck files created.
# 16500 bottleneck files created.
# 16600 bottleneck files created.
# 16700 bottleneck files created.
# 16800 bottleneck files created.
# 16900 bottleneck files created.
# 17000 bottleneck files created.
# 17100 bottleneck files created.
# 17200 bottleneck files created.
# 17300 bottleneck files created.
# 17400 bottleneck files created.
# 17500 bottleneck files created.
# 17600 bottleneck files created.
# 17700 bottleneck files created.
# 17800 bottleneck files created.
# 17900 bottleneck files created.
# 18000 bottleneck files created.
# 18100 bottleneck files created.
# 18200 bottleneck files created.
# 18300 bottleneck files created.
# 18400 bottleneck files created.
# 18500 bottleneck files created.
# 18600 bottleneck files created.
# 18700 bottleneck files created.
# 18800 bottleneck files created.
# 18900 bottleneck files created.
# 19000 bottleneck files created.
# 19100 bottleneck files created.
# 19200 bottleneck files created.
# 19300 bottleneck files created.
# 19400 bottleneck files created.
# 19500 bottleneck files created.
# 19600 bottleneck files created.
# 19700 bottleneck files created.
# 19800 bottleneck files created.
# 19900 bottleneck files created.
# 20000 bottleneck files created.
# 20100 bottleneck files created.
# 20200 bottleneck files created.
# 20300 bottleneck files created.
# 20400 bottleneck files created.
# 20500 bottleneck files created.
# 20600 bottleneck files created.
# 20700 bottleneck files created.
# 20800 bottleneck files created.
# 20900 bottleneck files created.
# 21000 bottleneck files created.
# 21100 bottleneck files created.
# 21200 bottleneck files created.
# 21300 bottleneck files created.
# 21400 bottleneck files created.
# 21500 bottleneck files created.
# 21600 bottleneck files created.
# 21700 bottleneck files created.
# 21800 bottleneck files created.
# 21900 bottleneck files created.
# 22000 bottleneck files created.
# 22100 bottleneck files created.
# 22200 bottleneck files created.
# 22300 bottleneck files created.
# 22400 bottleneck files created.
# 22500 bottleneck files created.
# 22600 bottleneck files created.
# 22700 bottleneck files created.
# 22800 bottleneck files created.
# 22900 bottleneck files created.
# 23000 bottleneck files created.
# 23100 bottleneck files created.
# 23200 bottleneck files created.
# 23300 bottleneck files created.
# 23400 bottleneck files created.
# 23500 bottleneck files created.
# 23600 bottleneck files created.
# 23700 bottleneck files created.
# 23800 bottleneck files created.
# 23900 bottleneck files created.
# 24000 bottleneck files created.
# 24100 bottleneck files created.
# 24200 bottleneck files created.
# 24300 bottleneck files created.
# 24400 bottleneck files created.
# 24500 bottleneck files created.
# 24600 bottleneck files created.
# 24700 bottleneck files created.
# 24800 bottleneck files created.
# 24900 bottleneck files created.
# 25000 bottleneck files created.
# 2017-05-17 15:18:54.044148: Step 0: Train accuracy = 94.0%
# 2017-05-17 15:18:54.044327: Step 0: Cross entropy = 0.622921
# 2017-05-17 15:18:54.128486: Step 0: Validation accuracy = 85.0% (N=100)
# 2017-05-17 15:18:54.937161: Step 10: Train accuracy = 100.0%
# 2017-05-17 15:18:54.937282: Step 10: Cross entropy = 0.298263
# 2017-05-17 15:18:55.008444: Step 10: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:18:55.774059: Step 20: Train accuracy = 99.0%
# 2017-05-17 15:18:55.774178: Step 20: Cross entropy = 0.182555
# 2017-05-17 15:18:55.841824: Step 20: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:18:56.603409: Step 30: Train accuracy = 99.0%
# 2017-05-17 15:18:56.603530: Step 30: Cross entropy = 0.142977
# 2017-05-17 15:18:56.680879: Step 30: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:18:57.433808: Step 40: Train accuracy = 100.0%
# 2017-05-17 15:18:57.433927: Step 40: Cross entropy = 0.114601
# 2017-05-17 15:18:57.500912: Step 40: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:18:58.238984: Step 50: Train accuracy = 100.0%
# 2017-05-17 15:18:58.239095: Step 50: Cross entropy = 0.100913
# 2017-05-17 15:18:58.305896: Step 50: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:18:59.072130: Step 60: Train accuracy = 100.0%
# 2017-05-17 15:18:59.072246: Step 60: Cross entropy = 0.081833
# 2017-05-17 15:18:59.150418: Step 60: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:18:59.899817: Step 70: Train accuracy = 99.0%
# 2017-05-17 15:18:59.899930: Step 70: Cross entropy = 0.079434
# 2017-05-17 15:18:59.979701: Step 70: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:00.764059: Step 80: Train accuracy = 99.0%
# 2017-05-17 15:19:00.764181: Step 80: Cross entropy = 0.063750
# 2017-05-17 15:19:00.837612: Step 80: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:01.589155: Step 90: Train accuracy = 99.0%
# 2017-05-17 15:19:01.589270: Step 90: Cross entropy = 0.083880
# 2017-05-17 15:19:01.664215: Step 90: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:02.418561: Step 100: Train accuracy = 99.0%
# 2017-05-17 15:19:02.418685: Step 100: Cross entropy = 0.078660
# 2017-05-17 15:19:02.485887: Step 100: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:03.219920: Step 110: Train accuracy = 100.0%
# 2017-05-17 15:19:03.220039: Step 110: Cross entropy = 0.063809
# 2017-05-17 15:19:03.288822: Step 110: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:04.039986: Step 120: Train accuracy = 100.0%
# 2017-05-17 15:19:04.040104: Step 120: Cross entropy = 0.051761
# 2017-05-17 15:19:04.110656: Step 120: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:04.863804: Step 130: Train accuracy = 99.0%
# 2017-05-17 15:19:04.863922: Step 130: Cross entropy = 0.068272
# 2017-05-17 15:19:04.935499: Step 130: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:05.704392: Step 140: Train accuracy = 99.0%
# 2017-05-17 15:19:05.704585: Step 140: Cross entropy = 0.062468
# 2017-05-17 15:19:05.773105: Step 140: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:06.520309: Step 150: Train accuracy = 98.0%
# 2017-05-17 15:19:06.520432: Step 150: Cross entropy = 0.059275
# 2017-05-17 15:19:06.587789: Step 150: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:07.294017: Step 160: Train accuracy = 100.0%
# 2017-05-17 15:19:07.294139: Step 160: Cross entropy = 0.052456
# 2017-05-17 15:19:07.360542: Step 160: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:08.092612: Step 170: Train accuracy = 100.0%
# 2017-05-17 15:19:08.092730: Step 170: Cross entropy = 0.053408
# 2017-05-17 15:19:08.161079: Step 170: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:08.905397: Step 180: Train accuracy = 99.0%
# 2017-05-17 15:19:08.905522: Step 180: Cross entropy = 0.062342
# 2017-05-17 15:19:08.977327: Step 180: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:09.717079: Step 190: Train accuracy = 100.0%
# 2017-05-17 15:19:09.717200: Step 190: Cross entropy = 0.054511
# 2017-05-17 15:19:09.786225: Step 190: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:10.509986: Step 200: Train accuracy = 100.0%
# 2017-05-17 15:19:10.510115: Step 200: Cross entropy = 0.028102
# 2017-05-17 15:19:10.581541: Step 200: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:11.289467: Step 210: Train accuracy = 98.0%
# 2017-05-17 15:19:11.289590: Step 210: Cross entropy = 0.054121
# 2017-05-17 15:19:11.366217: Step 210: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:12.107670: Step 220: Train accuracy = 99.0%
# 2017-05-17 15:19:12.107788: Step 220: Cross entropy = 0.054556
# 2017-05-17 15:19:12.176261: Step 220: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:12.892829: Step 230: Train accuracy = 100.0%
# 2017-05-17 15:19:12.892952: Step 230: Cross entropy = 0.040484
# 2017-05-17 15:19:12.960524: Step 230: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:13.667743: Step 240: Train accuracy = 99.0%
# 2017-05-17 15:19:13.667862: Step 240: Cross entropy = 0.054280
# 2017-05-17 15:19:13.734958: Step 240: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:14.491331: Step 250: Train accuracy = 99.0%
# 2017-05-17 15:19:14.491456: Step 250: Cross entropy = 0.043675
# 2017-05-17 15:19:14.566277: Step 250: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:15.295991: Step 260: Train accuracy = 99.0%
# 2017-05-17 15:19:15.296137: Step 260: Cross entropy = 0.035975
# 2017-05-17 15:19:15.363242: Step 260: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:16.099196: Step 270: Train accuracy = 99.0%
# 2017-05-17 15:19:16.099319: Step 270: Cross entropy = 0.050641
# 2017-05-17 15:19:16.171054: Step 270: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:16.895368: Step 280: Train accuracy = 99.0%
# 2017-05-17 15:19:16.895489: Step 280: Cross entropy = 0.032290
# 2017-05-17 15:19:16.963265: Step 280: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:17.706501: Step 290: Train accuracy = 99.0%
# 2017-05-17 15:19:17.706633: Step 290: Cross entropy = 0.035041
# 2017-05-17 15:19:17.774663: Step 290: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:18.486485: Step 300: Train accuracy = 100.0%
# 2017-05-17 15:19:18.486609: Step 300: Cross entropy = 0.026869
# 2017-05-17 15:19:18.558231: Step 300: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:19.307060: Step 310: Train accuracy = 100.0%
# 2017-05-17 15:19:19.307187: Step 310: Cross entropy = 0.027719
# 2017-05-17 15:19:19.378619: Step 310: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:20.102125: Step 320: Train accuracy = 100.0%
# 2017-05-17 15:19:20.102242: Step 320: Cross entropy = 0.024238
# 2017-05-17 15:19:20.170749: Step 320: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:20.898048: Step 330: Train accuracy = 99.0%
# 2017-05-17 15:19:20.898184: Step 330: Cross entropy = 0.048592
# 2017-05-17 15:19:20.969349: Step 330: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:21.695244: Step 340: Train accuracy = 98.0%
# 2017-05-17 15:19:21.695365: Step 340: Cross entropy = 0.053075
# 2017-05-17 15:19:21.767432: Step 340: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:22.506741: Step 350: Train accuracy = 98.0%
# 2017-05-17 15:19:22.506861: Step 350: Cross entropy = 0.060456
# 2017-05-17 15:19:22.577015: Step 350: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:23.307520: Step 360: Train accuracy = 98.0%
# 2017-05-17 15:19:23.307643: Step 360: Cross entropy = 0.046854
# 2017-05-17 15:19:23.380679: Step 360: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:24.116873: Step 370: Train accuracy = 100.0%
# 2017-05-17 15:19:24.116998: Step 370: Cross entropy = 0.034445
# 2017-05-17 15:19:24.185279: Step 370: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:24.918096: Step 380: Train accuracy = 99.0%
# 2017-05-17 15:19:24.918212: Step 380: Cross entropy = 0.036268
# 2017-05-17 15:19:24.992987: Step 380: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:25.747423: Step 390: Train accuracy = 100.0%
# 2017-05-17 15:19:25.747540: Step 390: Cross entropy = 0.019275
# 2017-05-17 15:19:25.818856: Step 390: Validation accuracy = 93.0% (N=100)
# 2017-05-17 15:19:26.558551: Step 400: Train accuracy = 100.0%
# 2017-05-17 15:19:26.558672: Step 400: Cross entropy = 0.021892
# 2017-05-17 15:19:26.626509: Step 400: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:27.368959: Step 410: Train accuracy = 99.0%
# 2017-05-17 15:19:27.369076: Step 410: Cross entropy = 0.033907
# 2017-05-17 15:19:27.439109: Step 410: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:28.181689: Step 420: Train accuracy = 100.0%
# 2017-05-17 15:19:28.181811: Step 420: Cross entropy = 0.024747
# 2017-05-17 15:19:28.249851: Step 420: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:28.982216: Step 430: Train accuracy = 100.0%
# 2017-05-17 15:19:28.982335: Step 430: Cross entropy = 0.024044
# 2017-05-17 15:19:29.053475: Step 430: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:29.783617: Step 440: Train accuracy = 99.0%
# 2017-05-17 15:19:29.783741: Step 440: Cross entropy = 0.034533
# 2017-05-17 15:19:29.851157: Step 440: Validation accuracy = 98.0% (N=100)
# 2017-05-17 15:19:30.581357: Step 450: Train accuracy = 100.0%
# 2017-05-17 15:19:30.581475: Step 450: Cross entropy = 0.019459
# 2017-05-17 15:19:30.653197: Step 450: Validation accuracy = 99.0% (N=100)
# 2017-05-17 15:19:31.373597: Step 460: Train accuracy = 100.0%
# 2017-05-17 15:19:31.373715: Step 460: Cross entropy = 0.022288
# 2017-05-17 15:19:31.443648: Step 460: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:32.189014: Step 470: Train accuracy = 99.0%
# 2017-05-17 15:19:32.189130: Step 470: Cross entropy = 0.032003
# 2017-05-17 15:19:32.257375: Step 470: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:32.973714: Step 480: Train accuracy = 99.0%
# 2017-05-17 15:19:32.973835: Step 480: Cross entropy = 0.032880
# 2017-05-17 15:19:33.053222: Step 480: Validation accuracy = 97.0% (N=100)
# 2017-05-17 15:19:33.783234: Step 490: Train accuracy = 97.0%
# 2017-05-17 15:19:33.783359: Step 490: Cross entropy = 0.074435
# 2017-05-17 15:19:33.851626: Step 490: Validation accuracy = 100.0% (N=100)
# 2017-05-17 15:19:34.504274: Step 499: Train accuracy = 100.0%
# 2017-05-17 15:19:34.504401: Step 499: Cross entropy = 0.017686
# 2017-05-17 15:19:34.572242: Step 499: Validation accuracy = 99.0% (N=100)
# Final test accuracy = 99.1% (N=2406)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.

# %%
def CatOrDog(image_path, labels_path='./retrained_labels.txt', graph_path='./retrained_graph.pb'):
    """
    A function to determine if "image_path" is a 
    picture of a cat or a dog. 
    
    - labels_path: Path of the labels used for classification
    - graph_path: Path of the TF graph 
    
    """
    import tensorflow as tf
    
    human_string = []
    score = []

    # Read in the image_data
    image_data = tf.gfile.FastGFile(image_path, 'rb').read()

    # Loads label file, strips off carriage return
    label_lines = [line.rstrip() for line 
                       in tf.gfile.GFile(labels_path)]
    
    # Unpersists graph from file
    with tf.gfile.FastGFile(graph_path, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        _ = tf.import_graph_def(graph_def, name='')

    with tf.Session() as sess:
        init = tf.global_variables_initializer()
        sess.run(init)

        # Feed the image_data as input to the graph and get first prediction
        softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')

        predictions = sess.run(softmax_tensor, {'DecodeJpeg/contents:0': image_data})

        # Sort to show labels of first prediction in order of confidence
        top_k = predictions[0].argsort()[-len(predictions[0]):][::-1]

        for node_id in top_k:
            #human_string = label_lines[node_id]
            #score = predictions[0][node_id]
            #print('%s (score = %.5f)' % (human_string, score))
            
            human_string.append(label_lines[node_id])
            score.append(predictions[0][node_id])
            
        return list(zip(human_string, score))

# %% [markdown]
# Let us check what the classfier tells us about an unseen picture:

# %%
image_path = './TestImageBo.jpg'
clf_result = CatOrDog(image_path)

print('This is an image with {0} with a score of {1}'.format(clf_result[0][0], clf_result[0][1]))
# Out:
# This is an image with cats with a score of 0.9953852295875549

# %% [markdown]
# Here is the picture ![](./TestImageBo.jpg)
